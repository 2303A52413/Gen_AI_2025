# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52413/Gen_AI_2025/blob/main/2303A52413_Gen_AI_W5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Question 1**
#
# A customer service center receives calls daily, with the number of calls ranging from 0 to 7 per
# day. The management wants to study the distribution of daily calls.
#  Generate a dataset representing the number of calls received per day for N days.
#  Compute and visualize the PMF and CDF to analyze the probability of receiving a
# specific number of calls on a given day.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

N = 1000
calls_per_day = np.random.randint(0, 8, N)

unique, counts = np.unique(calls_per_day, return_counts=True)
pmf = counts / N

cdf = np.cumsum(pmf)

plt.figure(figsize=(10, 5))
sns.barplot(x=unique, y=pmf, color='skyblue', edgecolor='black')
plt.xlabel("Number of Calls")
plt.ylabel("Probability")
plt.title("Probability Mass Function (PMF)")
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(unique, cdf, marker='o', linestyle='-', color='red')
plt.xlabel("Number of Calls")
plt.ylabel("Cumulative Probability")
plt.title("Cumulative Distribution Function (CDF)")
plt.grid()
plt.show()

# %% [markdown]
# **Question 2**
#
# A hospital receives emergency cases daily, and there is a 25% probability that a randomly arriving paƟent requires immediate surgery. Suppose N patients visit the emergency department in a day (N ≥ 100): i) What is the probability that exactly 20 patients need surgery? ii) What is the probability that at least 30 patients need surgery? iii) On average, how many patients requiring surgery should the hospital expect?

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

N = 100
p = 0.25

k_exact = 20
prob_exact_20 = stats.binom.pmf(k_exact, N, p)

prob_at_least_30 = 1 - stats.binom.cdf(29, N, p)

expected_surgery = N * p

print(f"Probability that exactly 20 patients need surgery: {prob_exact_20:.4f}")
print(f"Probability that at least 30 patients need surgery: {prob_at_least_30:.4f}")
print(f"On average, the hospital should expect {expected_surgery} patients requiring surgery.")

x = np.arange(0, N + 1)
pmf_values = stats.binom.pmf(x, N, p)

cdf_values = stats.binom.cdf(x, N, p)

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.bar(x, pmf_values, color='skyblue', label="PMF")
plt.title("Probability Mass Function (PMF)")
plt.xlabel("Number of Patients Needing Surgery")
plt.ylabel("Probability")
plt.xticks(np.arange(0, N + 1, 5))
plt.grid(True)

plt.subplot(1, 2, 2)
plt.step(x, cdf_values, where='post', color='orange', label="CDF")
plt.title("Cumulative Distribution Function (CDF)")
plt.xlabel("Number of Patients Needing Surgery")
plt.ylabel("Cumulative Probability")
plt.xticks(np.arange(0, N + 1, 5))
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Probability that exactly 20 patients need surgery: 0.0493
# Probability that at least 30 patients need surgery: 0.1495
# On average, the hospital should expect 25.0 patients requiring surgery.
